# %%
from root_histogram_analysis import *
# Out:
# Welcome to JupyROOT 6.30/04

# %%
xA0 = Histogram_Plotter('X','Amplitude', min_data=500)
xA0.adjust_both_bins_for_mc_and_data()
#xA0.plot_average_ratios_for_all_planes()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 xA0 = Histogram_Plotter('X','Amplitude', min_data=500)
# ----> 2 xA0.adjust_both_bins_for_mc_and_data()
#       3 #xA0.plot_average_ratios_for_all_planes()
#
# File ~/Desktop/WORK/Code/root_histogram_analysis.py:174, in Combined_Histograms.adjust_both_bins_for_mc_and_data(self)
#     171 data2_xn = np.sum(array2, axis = 1)
#     172 data2_yn = np.sum(array2, axis = 0)
# --> 174 data1_x = np.repeat(x_centers, data1_xn.astype(int))
#     175 data2_x = np.repeat(x_centers, data2_xn.astype(int))
#     176 data1_y = np.repeat(y_centers, data1_yn.astype(int))
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/fromnumeric.py:466, in repeat(a, repeats, axis)
#     423 @array_function_dispatch(_repeat_dispatcher)
#     424 def repeat(a, repeats, axis=None):
#     425     """
# ...

# %%
#canvas = ROOT.TCanvas()
#xA0.data_root.Draw()
#canvas.Update()

# %%
xA0.plot_2D_hist('data')

# %%
xys = Combined_3D_Histograms('Z','Y','FWHM',min_data= 10000, selected_plane= 0)
xys.plot_projection_ratios()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 xys = Combined_3D_Histograms('Z','Y','FWHM',min_data= 10000, selected_plane= 0)
# ----> 2 xys.plot_projection_ratios()
#
# File ~/Desktop/WORK/Code/root_histogram_analysis.py:575, in Combined_3D_Histograms.plot_projection_ratios(self)
#     573 plt.ylabel(self.ytitle)
#     574 plt.xlabel(self.xtitle)
# --> 575 title =  self.X + " vs " + self.Y + " " + self.Z + " Ratios (Data/Simulation) Plane: " + self.planetitle
#     576 plt.title(title)
#     577 plt.colorbar()
#
# TypeError: can only concatenate str (not "int") to str
# Warning in <TROOT::Append>: Replacing existing TH1: ZYFWHM (Potential memory leak).
